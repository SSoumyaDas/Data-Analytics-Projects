# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
zo=pd.read_csv("/content/Zomato.csv")
zo
# Out:
#                                  name online_order book_table   rate  votes  \
# 0                       Cafe Vivacity          Yes         No  3.8/5     87
# 1                        Chatar Patar           No         No  3.7/5     59
# 2                     Timepass Dinner          Yes         No  3.8/5    275
# 3                            T3H Cafe           No         No  3.9/5     85
# 4                              Faasos          Yes         No  4.2/5    385
# ..                                ...          ...        ...    ...    ...
# 995                           Spice 9           No         No  3.4/5      8
# 996                   The Big O Bakes           No         No  4.0/5     61
# 997      Naveen Kabab & Biriyani Mane           No         No  3.2/5     10
# 998  Dharwad Line Bazaar Mishra Pedha           No         No  3.4/5      0
# 999        Kotian Karavali Restaurant           No         No  3.5/5     10
#
#      approx_cost(for two people) listed_in(type)
# ...

# %%
zo.head()
# Out:
#               name online_order book_table   rate  votes  \
# 0    Cafe Vivacity          Yes         No  3.8/5     87
# 1     Chatar Patar           No         No  3.7/5     59
# 2  Timepass Dinner          Yes         No  3.8/5    275
# 3         T3H Cafe           No         No  3.9/5     85
# 4           Faasos          Yes         No  4.2/5    385
#
#    approx_cost(for two people) listed_in(type)
# 0                          650           Cafes
# 1                          330          Dining
# 2                          540          Buffet
# 3                          300           Cafes
# 4                          500           other

# %%
zo.shape
# Out:
# (1000, 7)

# %%
zo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   online_order                 1000 non-null   object
#  2   book_table                   1000 non-null   object
#  3   rate                         1000 non-null   object
#  4   votes                        1000 non-null   int64
#  5   approx_cost(for two people)  1000 non-null   int64
#  6   listed_in(type)              1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
zo.describe()
# Out:
#              votes  approx_cost(for two people)
# count  1000.000000                  1000.000000
# mean    256.382000                   419.340000
# std     631.161438                   226.604753
# min       0.000000                    90.000000
# 25%       6.000000                   220.000000
# 50%      43.500000                   390.000000
# 75%     218.250000                   600.000000
# max    5357.000000                  1040.000000

# %%
zo.describe(include=object)
# Out:
#                    name online_order book_table   rate listed_in(type)
# count              1000         1000       1000   1000            1000
# unique              145            2          2     20               4
# top     San Churro Cafe           No         No  3.8/5          Dining
# freq                 16          627        931    127             748

# %%
zo.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
zo.duplicated().sum()
# Out:
# np.int64(220)

# %%
for col in zo.columns:
    print(f"\n{col}:")
    print(zo[col].unique()[:20])
# Out:
# name:
# ['Cafe Vivacity' 'Chatar Patar' 'Timepass Dinner' 'T3H Cafe' 'Faasos'
#  "Domino's Pizza" 'Empire Restaurant' 'Ovenstory Pizza'
#  'Sri Basaveshwar Jolada Rotti Oota' 'Sri Sai Tiffannies' 'Onesta'
#  'Sri Guru Kottureshwara Davangere Benne Dosa' 'LSD Cafe' 'Goa 0 Km'
#  '360 Atoms Restaurant And Cafe' 'Jeet Restaurant' 'Vaishali Deluxe'
#  'Gustoes Beer House' 'Petoo' 'Floured-Baked With Love']
#
# online_order:
# ['Yes' 'No']
#
# book_table:
# ['No' 'Yes']
#
# rate:
# ['3.8/5' '3.7/5' '3.9/5' '4.2/5' '4.4/5' '3.4/5' '3.3/5' '4.6/5' '4.1/5'
#  '2.9/5' '3.6/5' '3.1/5' '4.0/5' '2.6/5' '2.8/5' '3.0/5' '3.2/5' '4.3/5'
#  '3.5/5' '3.8 /5']
#
# votes:
# [  87   59  275   85  385  560 5016  169    0 2344  558  147   12  779
#    43  902 5357  871   98   21]
#
# approx_cost(for two people):
# [650 330 540 300 500 800 750 150 630 400 850 770 580 360 600 660 200 550
#  760 440]
#
# listed_in(type):
# ['Cafes' 'Dining' 'Buffet' 'other']

# %%
zo=zo.drop_duplicates()
zo.shape
# Out:
# (780, 7)

# %%
zo.duplicated().sum()
# Out:
# np.int64(0)

# %%
zo['rate'].dtype
# Out:
# dtype('float64')

# %%
zo['rate'].head(10)
# Out:
# 0    3.8
# 1    3.7
# 2    3.8
# 3    3.9
# 4    4.2
# 5    3.9
# 6    4.4
# 7    3.9
# 8    3.4
# 9    3.3
# Name: rate, dtype: float64

# %%
zo['rate'].unique()
# Out:
# array([3.8, 3.7, 3.9, 4.2, 4.4, 3.4, 3.3, 4.6, 4.1, 2.9, 3.6, 3.1, 4. ,
#        2.6, 2.8, 3. , 3.2, 4.3, 3.5])

# %%
zo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 780 entries, 0 to 997
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         780 non-null    object
#  1   online_order                 780 non-null    object
#  2   book_table                   780 non-null    object
#  3   rate                         780 non-null    float64
#  4   votes                        780 non-null    int64
#  5   approx_cost(for two people)  780 non-null    int64
#  6   listed_in(type)              780 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 48.8+ KB

# %%
zo = zo.reset_index(drop=True)

# %%
zo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         780 non-null    object
#  1   online_order                 780 non-null    object
#  2   book_table                   780 non-null    object
#  3   rate                         780 non-null    float64
#  4   votes                        780 non-null    int64
#  5   approx_cost(for two people)  780 non-null    int64
#  6   listed_in(type)              780 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 42.8+ KB

# %%
print("Online Order:")
print(zo['online_order'].value_counts())

print("\nTable Booking:")
print(zo['book_table'].value_counts())

print("\nRestaurant Type:")
print(zo['listed_in(type)'].value_counts())
# Out:
# Online Order:
# online_order
# No     419
# Yes    361
# Name: count, dtype: int64
#
# Table Booking:
# book_table
# No     711
# Yes     69
# Name: count, dtype: int64
#
# Restaurant Type:
# listed_in(type)
# Dining    546
# Cafes     129
# other      54
# Buffet     51
# Name: count, dtype: int64

# %%
zo['rating_category'] = pd.cut(
    zo['rate'],
    bins=[0, 3, 4, 5],
    labels=['Low', 'Average', 'High'],
    right=False
)

# %%
zo['rating_category'].value_counts()
# Out:
# rating_category
# Average    527
# High       213
# Low         40
# Name: count, dtype: int64

# %%
zo['cost_category'] = pd.cut(
    zo['approx_cost(for two people)'],
    bins=[0, 300, 600, float('inf')],
    labels=['Budget', 'Moderate', 'Expensive'],
    right=False
)

# %%
zo['cost_category'].value_counts()
# Out:
# cost_category
# Moderate     323
# Expensive    247
# Budget       210
# Name: count, dtype: int64

# %%
zo['engagement_category'] = pd.cut(
    zo['votes'],
    bins=[-1, 100, 500, float('inf')],
    labels=['Low', 'Medium', 'High']
)

# %%
zo['engagement_category'].value_counts()
# Out:
# engagement_category
# Low       430
# Medium    207
# High      143
# Name: count, dtype: int64

# %% [markdown]
# # Q1: What type of restaurant is most common in the dataset?

# %%
zo['listed_in(type)'].value_counts()
# Out:
# listed_in(type)
# Dining    546
# Cafes     129
# other      54
# Buffet     51
# Name: count, dtype: int64

# %% [markdown]
# # Q2: Which restaurant type has the highest average rating?

# %%
zo.groupby('listed_in(type)')['rate'].mean().sort_values(ascending=False)
# Out:
# listed_in(type)
# other     4.020370
# Buffet    3.874510
# Cafes     3.814729
# Dining    3.616484
# Name: rate, dtype: float64

# %% [markdown]
# # Q3: Does accepting online orders relate to higher ratings?

# %%
zo.groupby('online_order')['rate'].mean().sort_values(ascending=False)
# Out:
# online_order
# Yes    3.877008
# No     3.536516
# Name: rate, dtype: float64

# %% [markdown]
# # Q4: Does table booking relate to higher customer ratings?

# %%
zo.groupby('book_table')['rate'].mean().sort_values(ascending=False)
# Out:
# book_table
# Yes    4.157971
# No     3.649086
# Name: rate, dtype: float64

# %% [markdown]
# # Q5: Does table booking also relate to higher customer engagement?

# %%
zo.groupby('book_table')['votes'].mean().sort_values(ascending=False)
# Out:
# book_table
# Yes    861.811594
# No     273.286920
# Name: votes, dtype: float64

# %% [markdown]
# # Q6: Which cost category has the highest average rating?

# %%
zo.groupby('cost_category')['rate'].mean().sort_values(ascending=False)
# Out:
# /tmp/ipykernel_832/2739730933.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   zo.groupby('cost_category')['rate'].mean().sort_values(ascending=False)
# cost_category
# Expensive    3.798785
# Moderate     3.708359
# Budget       3.549048
# Name: rate, dtype: float64

# %%
zo.groupby('cost_category', observed=True)['rate'].mean().sort_values(ascending=False)
# Out:
# cost_category
# Expensive    3.798785
# Moderate     3.708359
# Budget       3.549048
# Name: rate, dtype: float64

# %% [markdown]
# # Q7: Does restaurant cost relate to customer engagement?

# %%
zo.groupby('cost_category', observed=True)['votes'].mean().sort_values(ascending=False)
# Out:
# cost_category
# Expensive    660.352227
# Moderate     247.117647
# Budget        51.647619
# Name: votes, dtype: float64

# %% [markdown]
# # Q8: Does higher customer engagement correspond to higher ratings?

# %%
zo.groupby('engagement_category', observed=True)['rate'].mean().sort_values(ascending=False)
# Out:
# engagement_category
# High      4.062238
# Medium    3.834300
# Low       3.504186
# Name: rate, dtype: float64

# %% [markdown]
# # Q9: Which restaurants have the highest customer engagement?

# %%
zo.nlargest(10, 'votes')[['name', 'votes', 'rate', 'listed_in(type)']]
# Out:
#                   name  votes  rate listed_in(type)
# 18   Empire Restaurant   5357   4.4           other
# 425  Empire Restaurant   5352   4.4           other
# 114  Empire Restaurant   5097   4.4           other
# 6    Empire Restaurant   5016   4.4           other
# 488  Empire Restaurant   4884   4.4           other
# 768  Empire Restaurant   4670   4.4           other
# 611  Empire Restaurant   4636   4.4           other
# 298  Empire Restaurant   4545   4.4           other
# 295  Empire Restaurant   4502   4.4           other
# 110      Meghana Foods   4401   4.4          Dining

# %% [markdown]
# # Q10: Online Ordering vs Customer Engagement

# %%
zo.groupby('online_order')['votes'].mean().sort_values(ascending=False)
# Out:
# online_order
# Yes    585.850416
# No     100.906921
# Name: votes, dtype: float64

# %% [markdown]
# # Q11: What is the relationship between ratings and votes?

# %%
zo[['rate', 'votes']].corr()
# Out:
#            rate     votes
# rate   1.000000  0.491544
# votes  0.491544  1.000000

# %%
plt.figure(facecolor='lightgreen',figsize=(8,5))

count=sns.countplot(
    data=zo,
    x='listed_in(type)',
    order=zo['listed_in(type)'].value_counts().index,
    hue='rating_category',
    palette='twilight',
    width=0.5
)

plt.title('Distribution of Restaurant Types')
plt.xlabel('Restaurant Type')
plt.ylabel('Number of Restaurants')
plt.gca().set_facecolor('lightblue')


for i in count.containers:
  count.bar_label(i)
plt.show()

# %% [markdown]
# # Average Rating by Restaurant Type

# %%
rating_by_type = zo.groupby('listed_in(type)')['rate'].mean().sort_values(ascending=False)

plt.figure(facecolor='seagreen',figsize=(8,5))

bar=sns.barplot(
    x=rating_by_type.index,
    y=rating_by_type.values,
    hue=rating_by_type.index,
    palette='twilight',
    edgecolor='black',
    linewidth=1,
    width=0.5
)

for i in bar.containers:
  bar.bar_label(i)


plt.title('Average Rating by Restaurant Type')
plt.xlabel('Restaurant Type')
plt.ylabel('Average Rating')
plt.ylim(0, 5)

plt.gca().set_facecolor('powderblue')

plt.show()

# %% [markdown]
# # Online Order vs Average Rating

# %%
order_rating = zo.groupby('online_order')['rate'].mean()

plt.figure(facecolor='khaki', figsize=(7,5))

bar=sns.barplot(
    x=order_rating.index,
    y=order_rating.values,
    hue=order_rating.index,
    palette='muted',
    edgecolor='black',
    linewidth=1,
    width=0.4
)

plt.title('Average Rating by Online Order Availability')
plt.xlabel('Online Order')
plt.ylabel('Average Rating')
plt.ylim(0, 5)
plt.gca().set_facecolor('teal')
for i in bar.containers:
  bar.bar_label(i)

plt.show()

# %% [markdown]
# # Table Booking vs Average Rating

# %%
booking_rating = zo.groupby('book_table')['rate'].mean()

plt.figure(facecolor='skyblue',figsize=(7,5))

bar=sns.barplot(
    x=booking_rating.index,
    y=booking_rating.values,
    hue=booking_rating.index,
    palette='colorblind',
    edgecolor='black',
    linewidth=1,
    width=0.4
)

for i in bar.containers:
  bar.bar_label(i)

plt.title('Average Rating by Table Booking Availability')
plt.xlabel('Table Booking')
plt.ylabel('Average Rating')
plt.ylim(0, 5)
plt.gca().set_facecolor('moccasin')

plt.show()

# %% [markdown]
# # Cost Category vs Average Rating 💰

# %%
cost_rating = zo.groupby('cost_category', observed=True)['rate'].mean().sort_values(ascending=False)

plt.figure(facecolor='peachpuff',figsize=(8,5))

bar=sns.barplot(
    x=cost_rating.index,
    y=cost_rating.values,
    hue=cost_rating.index,
    palette='pastel',
    edgecolor='black',
    linewidth=1,
    width=0.4
)

for i in bar.containers:
  bar.bar_label(i)


plt.title('Average Rating by Cost Category')
plt.xlabel('Cost Category')
plt.ylabel('Average Rating')
plt.ylim(0, 5)
plt.gca().set_facecolor('khaki')
plt.show()

# %% [markdown]
# # Votes vs Rating

# %%
plt.figure(facecolor='lightcyan',figsize=(8,5))

sns.scatterplot(
    data=zo,
    x='votes',
    y='rate',
    alpha=0.6,
    color='blue'
)

plt.title('Relationship Between Votes and Ratings')
plt.xlabel('Number of Votes')
plt.ylabel('Rating')
plt.gca().set_facecolor('lightyellow')

plt.show()
